# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
from datetime import datetime

# %%
ticker = '^GSPC'
today=datetime.today().strftime('%Y-%m-%d')
SaP500= yf.download(ticker, start='2011-1-1', end='2021-1-1')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SaP500.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-12-31  1256.760010  1259.339966  1254.189941  1257.640015  1257.640015
# 2011-01-03  1257.619995  1276.170044  1257.619995  1271.869995  1271.869995
# 2011-01-04  1272.949951  1274.119995  1262.660034  1270.199951  1270.199951
# 2011-01-05  1268.780029  1277.630005  1265.359985  1276.560059  1276.560059
# 2011-01-06  1276.290039  1278.170044  1270.430054  1273.849976  1273.849976
#
#                 Volume
# Date
# 2010-12-31  1799770000
# 2011-01-03  4286670000
# 2011-01-04  4796420000
# 2011-01-05  4764920000
# 2011-01-06  4844100000

# %%
SaP500.iloc[-1]['Close']/SaP500.iloc[0]['Close']-
# Out:
# 2.9866019088215414

# %%
from forex_python.converter import CurrencyRates

# %%
cr=CurrencyRates()

# %%
start = '2020-07-01'
end = '2021-01-01'

rate = 'USDEUR=X'

# %%
yahoo_financials = YahooFinancials('USDLKR=X')

# %%
data = yahoo_financials.get_historical_price_data(start_date='1999-01-01', 
                                                  end_date='1999-12-31', 
                                                  time_interval='monthly')

# %%
data
# Out:
# {'USDLKR=X': {'eventsData': {},
#   'firstTradeDate': {'formatted_date': '2003-12-01', 'date': 1070236800},
#   'currency': 'LKR',
#   'instrumentType': 'CURRENCY',
#   'timeZone': {'gmtOffset': 3600},
#   'prices': [{'date': 1070236800,
#     'high': 98.01000213623047,
#     'low': 95.59500122070312,
#     'open': 96.20600128173828,
#     'close': 96.6500015258789,
#     'volume': 0,
#     'adjclose': 96.6500015258789,
#     'formatted_date': '2003-12-01'},
#    {'date': 1072915200,
#     'high': 98.92500305175781,
#     'low': 96.6500015258789,
#     'open': 96.6500015258789,
#     'close': 97.0999984741211,
#     'volume': 0,
#     'adjclose': 97.0999984741211,
#     'formatted_date': '2004-01-01'},
#    {'date': 1075593600,
#     'high': 99.25,
#     'low': 97.0999984741211,
#     'open': 97.0999984741211,
#     'close': 98.52999877929688,
#     'volume': 0,
#     'adjclose': 98.52999877929688,
#     'formatted_date': '2004-02-01'},
#    {'date': 1078099200,
# ...

# %%
import pandas as pd

YEAR=2010
CURR='LKR'
ln=f"https://fxtop.com/en/historical-exchange-rates.php?A=1&C1=USD&C2={CURR}&MA=1&DD1=01&MM1=01&YYYY1={YEAR}&B=1&P=&I=1&DD2=31&MM2=12&YYYY2={YEAR}&btnOK=Go%21"
df = pd.read_html(
    ln, header=0)[-3]
df.mean().iloc[0]
# Out:
# 113.20343700000001

# %%
year=2010
set(df['Month'])==set([ '{}/{}'.format(x,year) for x in range(1,13)])
# Out:
# True

# %%
set([ '{}/{}'.format(x,year) for x in range(1,13)])
# Out:
# {'1/2010',
#  '10/2010',
#  '11/2010',
#  '12/2010',
#  '2/2010',
#  '3/2010',
#  '4/2010',
#  '5/2010',
#  '6/2010',
#  '7/2010',
#  '8/2010',
#  '9/2010'}
